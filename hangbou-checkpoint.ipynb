# %%
import random 
# from words import word_list
word_list = ['wares','soup','mount','extend','brown','expert','tired',
             'humidity','backpack','crust','dent','market','knock','smite','windy','coin','throw',
    'silence']

hangman = [

"""
   _________
    |/        
    |              
    |                
    |                 
    |               
    |                   
    |___                 
    """,

"""
   _________
    |/   |      
    |              
    |                
    |                 
    |               
    |                   
    |___                 
    H""",

"""
   _________       
    |/   |              
    |   (_)
    |                         
    |                       
    |                         
    |                          
    |___                       
    HA""",

"""
   ________               
    |/   |                   
    |   (_)                  
    |    |                     
    |    |                    
    |                           
    |                            
    |___                    
    HAN""",


"""
   _________             
    |/   |               
    |   (_)                   
    |   /|                     
    |    |                    
    |                        
    |                          
    |___                          
    HANG""",


"""
   _________              
    |/   |                     
    |   (_)                     
    |   /|\                    
    |    |                       
    |                             
    |                            
    |___                          
    HANGM""",



"""
   ________                   
    |/   |                         
    |   (_)                      
    |   /|\                             
    |    |                          
    |   /                            
    |                                  
    |___                              
    HANGMA""",


"""
   ________
    |/   |     
    |   (_)    
    |   /|\           
    |    |        
    |   / \        
    |               
    |___           
    HANGMAN"""]   

print("Let's play hangman")
chosen_word = random.choice(word_list)

#print("The solution is: ",chosen_word)

display = []
word_lenth = len(chosen_word)
for i in range(word_lenth):
    display.append("_")

print(display)
live = 8
y = 0
end_of_game = False
while not end_of_game :
    guess = input("Guess a letter ").lower() 

    for position in range(word_lenth):
        letter = chosen_word[position]
        if letter == guess:
            display[position]=letter

    if guess not in chosen_word:
        live -= 1
        y = 8-live
        if live == 0:
            end_of_game = True
            print("You Lose.")
           
    print(display)
        
    if "_" not in display:
        end_of_game = True
        print("You win.")

    print(hangman[y])

# %%
# Game start
print("Let's Play Hangbou")
import random
word_list = ['wares','soup','mount','extend','brown','expert','tired',
             'humidity','backpack','crust','dent','market','knock','smite','windy','coin','throw',
    'silence']

hangman = [

"""
   _________
    |/        
    |              
    |                
    |                 
    |               
    |                   
    |___                 
    """,

"""
   _________
    |/   |      
    |              
    |                
    |                 
    |               
    |                   
    |___                 
    H""",

"""
   _________       
    |/   |              
    |   (_)
    |                         
    |                       
    |                         
    |                          
    |___                       
    HA""",

"""
   ________               
    |/   |                   
    |   (_)                  
    |    |                     
    |    |                    
    |                           
    |                            
    |___                    
    HAN""",


"""
   _________             
    |/   |               
    |   (_)                   
    |   /|                     
    |    |                    
    |                        
    |                          
    |___                          
    HANG""",


"""
   _________              
    |/   |                     
    |   (_)                     
    |   /|\                    
    |    |                       
    |                             
    |                            
    |___                          
    HANGB""",



"""
   ________                   
    |/   |                         
    |   (_)                      
    |   /|\                             
    |    |                          
    |   /                            
    |                                  
    |___                              
    HANGBO""",


"""
   ________
    |/   |     
    |   (_)    
    |   /|\           
    |    |        
    |   / \        
    |               
    |___           
    HANGBOU"""] 

#Chose a random wword from word list
chosen_word = random.choice(word_list)

print("Solution",chosen_word)
#Creat bLanks for all the letters
display=[]
length=len(chosen_word)
for i in range(length):
    display.append("_")
print(display)


# continue to ask the gamer for a letter until all are guessed

game_over = False
lives = 8
y=0
while not game_over:
    # As the gamer to guess a letter
    guess = input("Guess a letter ").lower() 
    
    
    # replace "_" with guess if correct
    for position in range(length):
        letter = chosen_word[position]
        if letter == guess:
            display[position]=letter 
        
    #lose life and print symbol is incorrect
    if guess not in chosen_word:
        lives -= 1
        y = 8-lives
        if lives == 0:
            game_over = True
            print("You Lose.")
    print(hangman[y])
    print(display)
    if "_" not in display:
        game_over = True
        print("You win.")
# Out:
# Let's Play Hangbou
# Solution knock
# ['_', '_', '_', '_', '_']
# Guess a letter j
#
#    _________
#     |/   |
#     |
#     |
#     |
#     |
#     |
#     |___
#     H
# ['_', '_', '_', '_', '_']
# Guess a letter k
#
#    _________
#     |/   |
#     |
#     |
#     |
#     |
#     |
#     |___
#     H
# ['k', '_', '_', '_', 'k']
# Guess a letter l
#
#    _________
#     |/   |
#     |   (_)
#     |
#     |
#     |
#     |
#     |___
#     HA
# ['k', '_', '_', '_', 'k']
# Guess a letter c
#
#    _________
#     |/   |
#     |   (_)
#     |
#     |
#     |
#     |
#     |___
#     HA
# ['k', '_', '_', 'c', 'k']
# Guess a letter n
#
#    _________
#     |/   |
#     |   (_)
#     |
#     |
#     |
#     |
#     |___
#     HA
# ['k', 'n', '_', 'c', 'k']
# Guess a letter o
#
#    _________
#     |/   |
#     |   (_)
#     |
#     |
#     |
#     |
#     |___
#     HA
# ['k', 'n', 'o', 'c', 'k']
# You win.
